# %% [markdown]
# # Neural Networks
#
# Neural Networks are powerful models inspired by biological neural netwroks. They consist of interconnected layers of neurons
# and can learn complex pattern in data. They are widely used in deep learning applications.

# %%
# Import Library 
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn.neural_network import MLPClassifier # Multi Layer Perceptron
# Out:
#   Cell In[1], line 3
#     Neural Networks are powerful models inspired by biological neural netwroks. They consist of interconnected layers of neurons
#            ^
# SyntaxError: invalid syntax
