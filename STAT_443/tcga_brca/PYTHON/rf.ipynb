# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
import pandas as pd 
import numpy as np

# %%
rf = RandomForestClassifier(n_estimators=100, 
                            max_features='sqrt', 
                            random_state=42)

# %%
# load dataset 

data = pd.read_csv("~/Documents/Github/PYTHON/STAT_443/tcga_brca/R/my_dataset_feb_14.txt", 
                   sep=" ", header=0)

# %%
print(data.columns)
# Out:
# Index(['disease_type', 'age_at_index', 'gender', 'race', 'vital_status',
#        'age_at_diagnosis', 'ajcc_pathologic_m', 'ajcc_pathologic_n',
#        'ajcc_pathologic_stage', 'ajcc_pathologic_t',
#        'ajcc_staging_system_edition', 'classification_of_tumor',
#        'diagnosis_is_primary_disease', 'icd_10_code', 'laterality',
#        'metastasis_at_diagnosis', 'method_of_diagnosis', 'primary_diagnosis',
#        'prior_malignancy', 'prior_treatment', 'site_of_resection_or_biopsy',
#        'sites_of_involvement', 'synchronous_malignancy',
#        'tissue_or_organ_of_origin', 'tumor_of_origin',
#        'initial_disease_status', 'margin_status', 'route_of_administration',
#        'therapeutic_agents', 'treatment_anatomic_sites',
#        'treatment_intent_type', 'treatment_or_therapy'],
#       dtype='object')

# %%
X = data.drop(columns=['vital_status'])
y = data["vital_status"]
y

X.dtypes
# Out:
# disease_type                     object
# age_at_index                    float64
# gender                           object
# race                             object
# age_at_diagnosis                float64
# ajcc_pathologic_m                object
# ajcc_pathologic_n                object
# ajcc_pathologic_stage            object
# ajcc_pathologic_t                object
# ajcc_staging_system_edition      object
# classification_of_tumor          object
# diagnosis_is_primary_disease     object
# icd_10_code                      object
# laterality                       object
# metastasis_at_diagnosis          object
# method_of_diagnosis              object
# primary_diagnosis                object
# prior_malignancy                 object
# prior_treatment                  object
# site_of_resection_or_biopsy      object
# sites_of_involvement             object
# synchronous_malignancy           object
# tissue_or_organ_of_origin        object
# tumor_of_origin                  object
# initial_disease_status           object
# margin_status                    object
# route_of_administration          object
# therapeutic_agents               object
# treatment_anatomic_sites         object
# treatment_intent_type            object
# treatment_or_therapy             object
# dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
rf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/qw/wh1hx7g97p3c9vlb0w44_2340000gn/T/ipykernel_97715/2725846524.py in ?()
# ----> 1 rf.fit(X_train, y_train)
#
# ~/Documents/Github/PYTHON/.venv/lib/python3.13/site-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1332                 skip_parameter_validation=(
#    1333                     prefer_skip_nested_validation or global_skip_validation
#    1334                 )
#    1335             ):
# -> 1336                 return fit_method(estimator, *args, **kwargs)
#
# ~/Documents/Github/PYTHON/.venv/lib/python3.13/site-packages/sklearn/ensemble/_forest.py in ?(self, X, y, sample_weight)
#     355         # Validate or convert input data
#     356         if issparse(y):
#     357             raise ValueError("sparse multilabel-indicator for y is not supported.")
#     358
# --> 359         X, y = validate_data(
#     360             self,
#     361             X,
#     362             y,
#
# ~/Documents/Github/PYTHON/.venv/lib/python3.13/site-packages/sklearn/utils/validation.py in ?(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2915             if "estimator" not in check_y_params:
#    2916                 check_y_params = {**default_check_params, **check_y_params}
#    2917             y = check_array(y, input_name="y", **check_y_params)
#    2918         else:
# -> 2919             X, y = check_X_y(X, y, **check_params)
#    2920         out = X, y
#    2921
#    2922     if not no_val_X and check_params.get("ensure_2d", True):
#
# ~/Documents/Github/PYTHON/.venv/lib/python3.13/site-packages/sklearn/utils/validation.py in ?(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1310         raise ValueError(
#    1311             f"{estimator_name} requires y to be passed, but the target y is None"
#    1312         )
#    1313
# -> 1314     X = check_array(
#    1315         X,
#    1316         accept_sparse=accept_sparse,
#    1317         accept_large_sparse=accept_large_sparse,
#
# ~/Documents/Github/PYTHON/.venv/lib/python3.13/site-packages/sklearn/utils/validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1019                         )
#    1020                     array = xp.astype(array, dtype, copy=False)
#    1021                 else:
#    1022                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1023             except ComplexWarning as complex_warning:
#    1024                 raise ValueError(
#    1025                     "Complex data not supported\n{}\n".format(array)
#    1026                 ) from complex_warning
#
# ~/Documents/Github/PYTHON/.venv/lib/python3.13/site-packages/sklearn/utils/_array_api.py in ?(array, dtype, order, copy, xp, device)
#     874         # Use NumPy API to support order
#     875         if copy is True:
#     876             array = numpy.array(array, order=order, dtype=dtype)
#     877         else:
# --> 878             array = numpy.asarray(array, order=order, dtype=dtype)
#     879
#     880         # At this point array is a NumPy ndarray. We convert it to an array
#     881         # container that is consistent with the input's namespace.
#
# ~/Documents/Github/PYTHON/.venv/lib/python3.13/site-packages/pandas/core/generic.py in ?(self, dtype, copy)
#    2167             )
#    2168         values = self._values
#    2169         if copy is None:
#    2170             # Note: branch avoids `copy=None` for NumPy 1.x support
# -> 2171             arr = np.asarray(values, dtype=dtype)
#    2172         else:
#    2173             arr = np.array(values, dtype=dtype, copy=copy)
#    2174
#
# ValueError: could not convert string to float: 'Ductal_and_Lobular_Neoplasms'
