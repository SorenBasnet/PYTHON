# %% [markdown]
# ## Piechart using seaborn
# Seaborn is a powerful Python data visualization library that simplifies the creation of attractive and informative statistical graphics.

# %%
import seaborn as sns 
import pandas as pd
