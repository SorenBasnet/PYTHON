# %% [markdown]
# ## This notebook shows how to use .columns in pandas

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'age': [99, 100], 
    'income': [100, 100]
})

print(df.columns)
# Out:
# Index(['age', 'income'], dtype='object')
